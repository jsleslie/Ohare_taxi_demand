# %% [markdown]
# java install instructions:
# https://www.digitalocean.com/community/tutorials/how-to-install-java-with-apt-on-ubuntu-18-04
# or
# https://www.oracle.com/java/technologies/javase-jdk14-downloads.html
#
# AutoML Code Examples:
# https://docs.h2o.ai/h2o/latest-stable/h2o-docs/automl.html#code-examples

# %%
import pandas as pd
import numpy as np
import h2o
from h2o.automl import H2OAutoML

# %%
ORD = pd.read_csv('../data/ORD.csv', index_col='Unnamed: 0')
ORD_train = ORD[ORD['year'] < 2018]

# %%
def lag_df(df, lag, cols):
    return df.assign(**{f"{col}-{n}": df[col].shift(n) for n in range(1, lag + 1) for col in cols})

# %%
lag = 3
ORD_train_lag = lag_df(ORD_train, lag=lag, cols=['seats'])

# %%
ORD_train_lag
# Out:
#        year  month  day  hour  rides   tmpf   dwpf       relh       sknt  \
# 0      2013      1    1     0     22  24.98  17.96  74.290000   9.000000
# 1      2013      1    1     1      9  24.89  17.78  73.995000   9.000000
# 2      2013      1    1     2     11  21.20  14.00  73.320000  10.000000
# 3      2013      1    1     3      3  21.14  12.14  67.723333  10.666667
# 4      2013      1    1     4      5  19.94  10.94  67.580000  10.000000
# ...     ...    ...  ...   ...    ...    ...    ...        ...        ...
# 43757  2017     12   31    19    159  12.90  -2.00  50.620000  12.769231
# 43758  2017     12   31    20    100  12.90  -2.90  48.500000  13.153846
# 43759  2017     12   31    21     62  10.90  -4.00  50.280000  12.307692
# 43760  2017     12   31    22     53   9.00  -4.00  54.740000  11.666667
# 43761  2017     12   31    23     30   7.00  -5.10  56.830000   9.538462
#
#        p01i       vsby       feel      skyc        seats  airline  \
# 0       0.0   9.000000  14.780000  3.000000   547.520724      3.0
# 1       0.0   8.000000  14.670000  5.000000   147.962430      1.0
# 2       0.0   9.000000   9.420000  5.000000          NaN      NaN
# 3       0.0   9.666667   8.976667  4.333333          NaN      NaN
# 4       0.0  10.000000   7.840000  5.000000   847.150186      4.0
# ...     ...        ...        ...       ...          ...      ...
# 43757   0.0  10.000000  -3.460000  2.923077  4652.273120     37.0
# 43758   0.0  10.000000  -2.900000  0.230769  2201.296388     15.0
# 43759   0.0  10.000000  -5.460000  0.230769  1456.971367     10.0
# 43760   0.0  10.000000  -5.090000  0.307692  1368.781483      9.0
# 43761   0.0  10.000000  -8.380000  0.153846  1994.739251     11.0
#
#            seats-1      seats-2      seats-3
# 0              NaN          NaN          NaN
# 1       547.520724          NaN          NaN
# 2       147.962430   547.520724          NaN
# 3              NaN   147.962430   547.520724
# 4              NaN          NaN   147.962430
# ...            ...          ...          ...
# 43757  6279.424095  3469.881437  4896.180254
# 43758  4652.273120  6279.424095  3469.881437
# 43759  2201.296388  4652.273120  6279.424095
# 43760  1456.971367  2201.296388  4652.273120
# 43761  1368.781483  1456.971367  2201.296388
#
# [43762 rows x 18 columns]

# %%
ORD_train_lag.to_csv('../data/train_data.csv')

# %%
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 . connected.
# --------------------------  ------------------------------------------------------------------
# H2O_cluster_uptime:
td><td style="text-align: right;">nan       </td></tr>
# <tr><td>DRF_1_AutoML_20200607_195151                       </td><td style="text-align: right;">                 2530.65</td><td style="text-align: right;">50.3056</td><td style="text-align: right;">2530.65</td><td style="text-align: right;">35.9405</td><td style="text-align: right;">  0.394156</td></tr>
# <tr><td>XRT_1_AutoML_20200607_195151                       </td><td style="text-align: right;">                 2595.79</td><td style="text-align: right;">50.9489</td><td style="text-align: right;">2595.79</td><td style="text-align: right;">36.3871</td><td style="text-align: right;">  0.397478</td></tr>
# <tr><td>XGBoost_grid__1_AutoML_20200607_195151_model_2     </td><td style="text-align: right;">                 3059.49</td><td style="text-align: right;">55.3127</td><td style="text-align: right;">3059.49</td><td style="text-align: right;">39.376 </td><td style="text-align: right;">nan       </td></tr>
# <tr><td>DeepLearning_grid__1_AutoML_20200607_195151_model_1</td><td style="text-align: right;">                 4334.65</td><td style="text-align: right;">65.8381</td><td style="text-align: right;">4334.65</td><td style="text-align: right;">49.3532</td><td style="text-align: right;">nan       </td></tr>
# <tr><td>DeepLearning_1_AutoML_20200607_195151              </td><td style="text-align: right;">                 4390.71</td><td style="text-align: right;">66.2624</td><td style="text-align: right;">4390.71</td><td style="text-align: right;">49.315 </td><td style="text-align: right;">nan       </td></tr>
# <tr><td>GLM_1_AutoML_20200607_195151                       </td><td style="text-align: right;">                 6251.97</td><td style="text-align: right;">79.0694</td><td style="text-align: right;">6251.97</td><td style="text-align: right;">62.8591</td><td style="text-align: right;">nan       </td></tr>
# <tr><td>DeepLearning_grid__2_AutoML_20200607_195151_model_1</td><td style="text-align: right;">                 8891.37</td><td style="text-align: right;">94.2941</td><td style="text-align: right;">8891.37</td><td style="text-align: right;">78.127 </td><td style="text-align: right;">nan       </td></tr>
# </tbody>
# </table>

# %%
model_ids = list(aml.leaderboard['model_id'].as_data_frame().iloc[:,0])

# %%
model_ids
# Out:
# ['StackedEnsemble_AllModels_AutoML_20200607_195151',
#  'StackedEnsemble_BestOfFamily_AutoML_20200607_195151',
#  'GBM_4_AutoML_20200607_195151',
#  'GBM_3_AutoML_20200607_195151',
#  'GBM_2_AutoML_20200607_195151',
#  'GBM_5_AutoML_20200607_195151',
#  'GBM_grid__1_AutoML_20200607_195151_model_2',
#  'XGBoost_grid__1_AutoML_20200607_195151_model_4',
#  'GBM_1_AutoML_20200607_195151',
#  'XGBoost_3_AutoML_20200607_195151',
#  'GBM_grid__1_AutoML_20200607_195151_model_1',
#  'XGBoost_grid__1_AutoML_20200607_195151_model_3',
#  'XGBoost_grid__1_AutoML_20200607_195151_model_1',
#  'XGBoost_1_AutoML_20200607_195151',
#  'XGBoost_2_AutoML_20200607_195151',
#  'DRF_1_AutoML_20200607_195151',
#  'XRT_1_AutoML_20200607_195151',
#  'XGBoost_grid__1_AutoML_20200607_195151_model_2',
#  'DeepLearning_grid__1_AutoML_20200607_195151_model_1',
#  'DeepLearning_1_AutoML_20200607_195151',
#  'GLM_1_AutoML_20200607_195151',
#  'DeepLearning_grid__2_AutoML_20200607_195151_model_1']

# %%
m = h2o.get_model([mid for mid in model_ids if "GBM_4" in mid][0])

# %%
m
# Out:
# Model Details
# =============
# H2OGradientBoostingEstimator :  Gradient Boosting Machine
# Model Key:  GBM_4_AutoML_20200607_195151
#
#
# Model Summary:
#      number_of_trees  number_of_internal_trees  model_size_in_bytes  \
# 0              262.0                     262.0             874253.0
#
#    min_depth  max_depth  mean_depth  min_leaves  max_leaves  mean_leaves
# 0       10.0       10.0        10.0        75.0       682.0    261.17557
# ModelMetricsRegression: gbm
# ** Reported on train data. **
#
# MSE: 379.2979340605132
# RMSE: 19.47557275308003
# MAE: 14.156868321803845
# RMSLE: NaN
# Mean Residual Deviance: 379.2979340605132
#
# ModelMetricsRegression: gbm
# ** Reported on cross-validation data. **
#
# MSE:
# See the whole table with table.as_data_frame()
#
# Variable Importances:
#    variable  relative_importance  scaled_importance  percentage
# 0   seats-2         2.156654e+09           1.000000    0.530450
# 1        C1         3.939285e+08           0.182657    0.096891
# 2      hour         3.883205e+08           0.180057    0.095511
# 3   seats-1         3.218258e+08           0.149225    0.079156
# 4   seats-3         2.365267e+08           0.109673    0.058176
# 5     month         9.215785e+07           0.042732    0.022667
# 6       day         8.196591e+07           0.038006    0.020160
# 7     seats         8.175986e+07           0.037911    0.020110
# 8      year         5.864750e+07           0.027194    0.014425
# 9   airline         4.816669e+07           0.022334    0.011847
# 10     dwpf         4.035895e+07           0.018714    0.009927
# 11     tmpf         3.619787e+07           0.016784    0.008903
# 12     feel         3.505414e+07           0.016254    0.008622
# 13     relh         2.816501e+07           0.013060    0.006927
# 14     sknt         2.725068e+07           0.012636    0.006703
# 15     skyc         2.323918e+07           0.010776    0.005716
# 16     vsby         1.114363e+07           0.005167    0.002741
# 17     p01i         4.341141e+06           0.002013    0.001068

# %%
model_ids
# Out:
# ['StackedEnsemble_AllModels_AutoML_20200607_195151',
#  'StackedEnsemble_BestOfFamily_AutoML_20200607_195151',
#  'GBM_4_AutoML_20200607_195151',
#  'GBM_3_AutoML_20200607_195151',
#  'GBM_2_AutoML_20200607_195151',
#  'GBM_5_AutoML_20200607_195151',
#  'GBM_grid__1_AutoML_20200607_195151_model_2',
#  'XGBoost_grid__1_AutoML_20200607_195151_model_4',
#  'GBM_1_AutoML_20200607_195151',
#  'XGBoost_3_AutoML_20200607_195151',
#  'GBM_grid__1_AutoML_20200607_195151_model_1',
#  'XGBoost_grid__1_AutoML_20200607_195151_model_3',
#  'XGBoost_grid__1_AutoML_20200607_195151_model_1',
#  'XGBoost_1_AutoML_20200607_195151',
#  'XGBoost_2_AutoML_20200607_195151',
#  'DRF_1_AutoML_20200607_195151',
#  'XRT_1_AutoML_20200607_195151',
#  'XGBoost_grid__1_AutoML_20200607_195151_model_2',
#  'DeepLearning_grid__1_AutoML_20200607_195151_model_1',
#  'DeepLearning_1_AutoML_20200607_195151',
#  'GLM_1_AutoML_20200607_195151',
#  'DeepLearning_grid__2_AutoML_20200607_195151_model_1']

# %%
model = h2o.get_model(model_ids[3])

# %%
model_ids[15]
# Out:
# 'DRF_1_AutoML_20200607_195151'

# %%
import os
h2o.save_model(model=h2o.get_model(model_ids[2]), path=os.getcwd()+"/../data/models", force=True)
h2o.save_model(model=h2o.get_model(model_ids[7]), path=os.getcwd()+"/../data/models", force=True)
h2o.save_model(model=h2o.get_model(model_ids[15]), path=os.getcwd()+"/../data/models", force=True)
h2o.save_model(model=h2o.get_model(model_ids[16]), path=os.getcwd()+"/../data/models", force=True)
h2o.save_model(model=h2o.get_model(model_ids[20]), path=os.getcwd()+"/../data/models", force=True)
# Out:
# '/home/dkruszew/Repos/Ohare_taxi_demand/data/models/GLM_1_AutoML_20200607_195151'
